# %%
import pandas

# %%
import pandas 
df1 = pandas.read_csv("traffic.csv")
df1
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
import pandas
df2 = pandas.read_excel("traffic.xlsx")
df2
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
import pandas
df3 = pandas.read_json("traffic.json")
df3
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df2
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df2.set_index("Date")
df2
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
import pandas
df1 = pandas.read_csv("traffic.csv",header=None)
df1
# Out:
#        0         1   2          3       4          5
# 0   Date  Visitors  BR    Country  Clicks        Day
# 1      1      1500  20        USA      20    Tuesday
# 2      2       700  25         UK      35  Wednesday
# 3      3       900  15      India      37   Thursday
# 4      4       400  35        USA      12     Friday
# 5      5       500  14     Canada      35   Saturday
# 6      6       700  15      India      32     Sunday
# 7      7       600  20      India      37     Monday
# 8      8       700  16        USA      40    Tuesday
# 9      9      1200  27        USA      52  Wednesday
# 10    10      1400  32  Australia      57   Thursday

# %%
df2.set_index("Day")
# Out:
#            Date  Visitors  BR    Country  Clicks
# Day
# Tuesday       1      1500  20        USA      20
# Wednesday     2       700  25         UK      35
# Thursday      3       900  15      India      37
# Friday        4       400  35        USA      12
# Saturday      5       500  14     Canada      35
# Sunday        6       700  15      India      32
# Monday        7       600  20      India      37
# Tuesday       8       700  16        USA      40
# Wednesday     9      1200  27        USA      52
# Thursday     10      1400  32  Australia      57

# %%
df3 = df2.set_index("Day")
df3
# Out:
#            Date  Visitors  BR    Country  Clicks
# Day
# Tuesday       1      1500  20        USA      20
# Wednesday     2       700  25         UK      35
# Thursday      3       900  15      India      37
# Friday        4       400  35        USA      12
# Saturday      5       500  14     Canada      35
# Sunday        6       700  15      India      32
# Monday        7       600  20      India      37
# Tuesday       8       700  16        USA      40
# Wednesday     9      1200  27        USA      52
# Thursday     10      1400  32  Australia      57

# %%
df2 = df2.set_index ("Day")
df2
# Out:
#            Date  Visitors  BR    Country  Clicks
# Day
# Tuesday       1      1500  20        USA      20
# Wednesday     2       700  25         UK      35
# Thursday      3       900  15      India      37
# Friday        4       400  35        USA      12
# Saturday      5       500  14     Canada      35
# Sunday        6       700  15      India      32
# Monday        7       600  20      India      37
# Tuesday       8       700  16        USA      40
# Wednesday     9      1200  27        USA      52
# Thursday     10      1400  32  Australia      57

# %%
df4 = pandas.read_csv("traffic-commas.txt")
df4
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df5 = pandas.read_csv("traffic-semi-colons.txt")
df5
# Out:
#   Date;Visitors;BR;Country;Clicks;Day
# 0            1;1500;20;USA;20;Tuesday
# 1            2;700;25;UK;35;Wednesday
# 2          3;900;15;India;37;Thursday
# 3              4;400;35;USA;12;Friday
# 4         5;500;14;Canada;35;Saturday
# 5            6;700;15;India;32;Sunday
# 6            7;600;20;India;37;Monday
# 7             8;700;16;USA;40;Tuesday
# 8          9;1200;27;USA;52;Wednesday
# 9    10;1400;32;Australia;57;Thursday

# %%
df5 = pandas.read_csv("traffic-semi-colons.txt", sep=";")
df5
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df6 = pandas.read_csv("http://www.sharecsv.com/dl/12746a580c502de45dd2994d331b/traffic.csv")
df6
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29452\1033862154.py in <module>
# ----> 1 df6 = pandas.read_csv("http://www.sharecsv.com/dl/12746a580c502de45dd2994d331b/traffic.csv")
#       2 df6
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df7 = pandas_json("https//api.myjson.com/bins/civ3k")
df7

# %%
df1.loc[2:5, "country":"click"]
df1
# Out:
#        0         1   2          3       4          5
# 0   Date  Visitors  BR    Country  Clicks        Day
# 1      1      1500  20        USA      20    Tuesday
# 2      2       700  25         UK      35  Wednesday
# 3      3       900  15      India      37   Thursday
# 4      4       400  35        USA      12     Friday
# 5      5       500  14     Canada      35   Saturday
# 6      6       700  15      India      32     Sunday
# 7      7       600  20      India      37     Monday
# 8      8       700  16        USA      40    Tuesday
# 9      9      1200  27        USA      52  Wednesday
# 10    10      1400  32  Australia      57   Thursday

# %%
df2 = df1.loc[2:5, "country":"Day"]
df1
# Out:
#        0         1   2          3       4          5
# 0   Date  Visitors  BR    Country  Clicks        Day
# 1      1      1500  20        USA      20    Tuesday
# 2      2       700  25         UK      35  Wednesday
# 3      3       900  15      India      37   Thursday
# 4      4       400  35        USA      12     Friday
# 5      5       500  14     Canada      35   Saturday
# 6      6       700  15      India      32     Sunday
# 7      7       600  20      India      37     Monday
# 8      8       700  16        USA      40    Tuesday
# 9      9      1200  27        USA      52  Wednesday
# 10    10      1400  32  Australia      57   Thursday

# %%
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: [2, 3, 4, 5]

# %%
df2 = df1.loc [3,"clicks"]
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'clicks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29452\3247153911.py in <module>
# ----> 1 df2 = df1.loc [3,"clicks"]
#       2 df2
#
# ...

# %%
df2 = df1.loc[:, "clicks"]
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'clicks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29452\673390802.py in <module>
# ----> 1 df2 = df1.loc[:, "clicks"]
#       2 df2
#
# ...

# %%
df1 = pandas.read_csv("traffic.csv")
df1
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df1.iloc[6:9, 1:5]
# Out:
#    Visitors  BR Country  Clicks
# 6       600  20   India      37
# 7       700  16     USA      40
# 8      1200  27     USA      52

# %%
df1.iloc[5,1:5]
# Out:
# Visitors      700
# BR             15
# Country     India
# Clicks         32
# Name: 5, dtype: object

# %%
df1.ix[5, 1:6]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29452\3557276099.py in <module>
# ----> 1 df1.ix[5, 1:6]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
